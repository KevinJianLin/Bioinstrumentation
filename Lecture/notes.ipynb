# %% [markdown]
# **definition:**
#
# ||       : components are connnected in parallel situation
#
# +        : components are connected in series situation
#
# $A_{dm}$ : differential mode gain
#
# $A_{cm}$ : common-mode gain
#
# Branch   : the one with component
# C        : capacitance of capacitor and unit is Farad(F),pF(pico F)
# CMRR     : Common-mode rejection ratio (CMRR), ratio of differetial gain divided by
#            common mode gain,
# CMR      : CMR and CMRR is interchangable
# f        : frequency which is 1/T where T is period of signal strength highesst to lowest
# $f_c$    : cut off frequency in Hz unit,
# H        : filter response,
# I        : electrical current unit is Amperes or Coulombs per second (C/s)
# J        : Jouels, called energy. It's integration of power over time
# j        : imaginary y-axis in phasor complex number sinusoid
# loop     : a collection of branch with same node and does not pass through element twice
# L        : refers to inductance provided by inductor and unit is Henry(H)
# $L_r$    : ripple attenuation at pass band which ripple value in y-axis,the frequency                where ripple generates, how does ripple generates??number of ripple is                    equivalent to number of order divided by 2;-20dB/decade means rate of                    decreasing signal
# P        : Power, unit is watts, equivalent to curren time voltage, (C/s)*(j/c) = j/s or watts
# RC       : RC circuit stands for resistor and capacitor circuit, single-pole meaning only            one resistor and one capacitor
# rolloff  : the rate of loss or attenuation of a signal beyond certain frequency
# T        : period, basically it's time. a cycle that starts from 0 and go through minimum            and maximum and come back to original point. unit is second(s)
#
#
#
# ω       : 2 π f callled angular frquency and unit is radius/second.
#
# $ω_0$   : mid band frequency
#
# $ω_c$   : 3-dB or cut-off frequency in rad/S unit,1/CR
#
# V        : unit is voltage or Joules per coulomb(J/C),voltage, push electron from
#          one point to another unit is Jouels/co
# V(t)     : voltage in a function of time or frequency
#
# $V_m$    : the peak amplitude of the voltage the maximum value
#
#
# Nodes    : a the loop without component
#
# n        : order of filter is equivalent number of capacitor and inductor in the circuit
#
# $X_c$    : refers to reactance of a capacitor and can be calculated as 1/(2 π f C)
#
# z        : phasor or complex number represents a sinusoid
#
# Z        : means Impedance which is opposite of current flow and can be calculated as
#           square root($R^2$ + Xc ^2)
# $Z_r$    : resistor impedance , value is exactly equal to resistor value for a pure                  resistor
# $Z_c$    : capacitor impedance
# $Z_L$    : refers to inductor impedance, value is jωL
# g        : refers to number of elements in low pass filter(this is wrong statement),

# %% [markdown]
# **Formula:**
#
#        Impedance (Z):
# $Z_r$= R  a resistor's impedance is equalalent to its resistance
#
# $Z_c$=$\frac{1}{jωC}$  capacitor's impedance
#
# $Z_L$=jωL  inductor's impedance
#
#        cut off angular frequency rad/s for low pass filter
# $ω_c$=$\frac{1}{R C}$ where R is impedance of the resistor and C is capacitanc of                capacitor
#
#        cut off phase?? frequency unit is Herz for low pass filter
# $f_c$ = $\frac{1}{2 * \pi * C * R }$
#
#        capacitance
# C = $\frac{1}{2 *\pi * R * f_c}$
#        where R is reactance of resistor, and $f_c$ is cutoff frequency in Hz
#
#        low-pass filter general response for low pass filter
#
# $\frac{V_o}{V_s}$ = $\frac{1}{\sqrt(1+ (ωRC)^2)}$
#        where ω is source frequency
#
#
# H(jω) = $\frac{1}{\sqrt(1+\frac{ω}{ω_0}}$
#       since it's ratio between output voltage and input voltage,  so there is no unit.
#       We want response in dB, then we need to take
#
# $H(jω)_dB$= 20log(H(jω)) where   H(jω) refers to output voltage divided by input outage
#
#        high pass filter response of capacitor + resitor circuit, current I is                cancelled it out
#
# $\frac{V_o}{V_i}$ = $\frac{R}{R+\frac{1}{jωC}}$
#
# $\frac{V_o}{V_i}$ = $\frac{jωRC}{jωRC+1}$
#
#        high pass filter response of  resitor + capacitor circuit,
#
#  $\frac{V_o}{V_i}$ = $\frac{z*ω*L}{R+z*ω*L}$
#        where when ω 0 , gain is 0 and when ω is infinite, gain is 1.
#
#
#        number of elements (n) for low-pass filter   lecture 6 slide 38
#
# $\frac{A}{10}$
# n = $\frac{log(10^\frac{A}{10} - 1)}{2log(\frac{ω1}{ωc})}$
#        low-pass filter general response
# H(jω) = $\frac{1}{\sqrt(1+\frac{ω}{ω_0}}$
#
#        A is attenuation at ω1, where $ω_c$ is cut off frequency. ω1 > ωc. unit for A is dB
#
#        1GHz = 1000 MHz = 1 000 000 Hz
#       Maximally flat or Butterworth low pass filter ratio response:
#       N section low pass filter including shunt and series
#
# H(ω) = $\frac{1}{1+C^2(\frac{ω}{ω_c})^2*n)}$
# $g_k$ =  2sin($\frac{(2k-1)\pi}{2n}$)  lecture 6 slide 36
# $L_k$ = $\frac{Z_o g_k}{\omega_c}$     lecture 6 slide 36
# $C_k$ = $\frac{g_k}{Z_0 ω}$
#
#       N section high pass filter tranafering from low pass filter shunt and series
#
# $C_k$  = $\frac{1}{Z_o g_k ω_c}$ inductor replace by capacitor
#
# $L_k$  = $\frac{Z_0}{g_k ω_c}$ capactior replaced by inductor
#
# $L_{k}^{'}$ = $\frac{R_0}{ω_c C_k}$
#
# $C_{k}{'}$ = $\frac{1}{R_0 ω_c L_k}$
#
#       N section band pass filter tranafering from low pass filter shunt and series
#
# $\Omega$ = $\frac{ω_2 - ω_1}{ω_0}$
# $\Omega$ is bandwidth
#
# $f_r$ = $\frac{1}{2\pi\sqrt(R_1C_1R_2C_2)}$ refers to centre frequency
#
# $\ω_0$ = $\sqrt(ω_1 ω_2)$
#      One of good feature about op-amp is it has a good high imput impedance and low
#      output impedance because voltage in output gets large??
#
# $f_H$ = $\frac{1}{2\pi R_1 C_1}$ where this refers to high input impedance from
#                                  assignment 1
#
# $f_L$ = $\frac{1}{2\pi R_2 C_2}$ where this refers to low input impedance base on
#                                  assignment 1
#
# $L_{s_k}$ = $\frac{Z_o g_1}{\Omega ω_0}$
#
# $C_{s_k}$ = $\frac{\Omega}{ω_0 Z_o g_1}$
#
# $L_{p_k}$ = $\frac{\Omega Z_0}{ω_0 g_2}$
#
# $C_{p_k}$ = $\frac{g_2}{Z_0 \Omega ω_0}$
#
#
#
#        where k = 1, 2, 4, .....n; $Z_o$ is resistance of resistor and unit is ohm
# $\omega_c$ is cutoff angular frequency and unit is radius/s.
#
#        Maximally flat or Butterworth low pass filter ratio response:
# $Z_o$ is resistance of resistor and unit is ohm
#
#       Equal-ripple low-pass lower ratio filter response:
#
# H(ω) = $\frac{1}{1+ F_o C_n^2(\frac{ω}{ω_c})}$ refer to lecture 6 slide 42
#
# $C_n$(x): Chebyshev polynomial for n order, x = $\frac{ω}{\ω_c}$
#
#
#       constant related to passband ripple
# $F_o$ = $10^\frac{Lr}{10}$ -1
#
# $C_o$(X) = 1 ???? ;
#
# $C_1$(X) = x = $\frac{ω}{ω_c}$;
#
# $C_n$(X) = 2 X $C_{n-1}$(X) - $C_{n-2}$(X)
#
# $C_n$(1) =1 in case of ω = $ω_c$
#
# $g_o$ =1;
#
# $g_1$ = 2$\frac{a_1}{F_2}$
#
#
# $g_k$ = $\frac{4a_{k-1}a_{k}{b_{k-1}g_{k-1}}$ where k = 2,....n
#
# $g_{n+1}$ = 1 if n is odd
#
# $g_{n+1}$ = $coth^2(F_1)$ for n is even
#
#
#                Lr formula is
# F1 = 0.25 ln{coth($\frac{L_r}{17.372}$)} => slide 42, what is F1 and F2??
#
# F2 = sinh ($\frac{2F1}{n})$
#
# $a_k$ = sin{$\frac{(2k-1)\pi}{2n}$} where k = 1,2,3...n
#
# $b_k$ = $F_2^2$ + $sin^2$($\frac{k\pi}{n}$)

# %%
EExercises: 

Lecture 1 slide 39    
Vec + 4 + 6 = 0; then we can find Vec;

needs to work on KCL and KVL to find;    


Lecture 2 exercises b
KCL @ b:I1 - 12 + 4 = 0, then we can find I1, this


KCL @ c : -4 + 12 -I2-3 = 0;


    
    
Lecture 2 slide 43   
solve the equation:
    
    0.1 V1 - 0.2 j V1 + 0.2 j V2 = - j 2 
    0.1 j V2 - 0.2 j V2 + 0.2 j V1 = 1.5
    
    what is j then ?
    it seems like theta 0 = 0; theta 90 = j. This is true ,
    
    
    need to solve that equation.????
    
Lecture 3 page 13:
    
    KVL does not have be be physical loop
    in this case, KVL @ L is DBC loop which is clockwise, current direction is B -> C and D -> C
    How do we know that point D is negative voltage and point ???
    
    
Lecture 3 slide 57???    
Lecture 5 slide 10:
    this is inverting amp because positive source pass through negative side of amp
    in one loop, the voltage is differnt but current is same
    in this case, Vs is source and it pass through R1 which consumes certain amount of voltage, oh
yeah, that is KVL rule. (Vs - Vn) /R1 = I1, (V0 - Vn) / R2 is equal to I2. 
  
     according to op amp rule, input current is 0 meaning that both entering point of amplifier 
        
and existing point of amplifier is 0. susbtitue in

    will get V0 /Vs =  - R2/R1
    
    

Lecture 5 slide 11:
    if providing voltage source goes into positive side of op amplifier, it's considered to
    be non-inverting amplider. We are interested in konwing Vs and Vo releationship. 
    same idea apply, KCL rule, choose node at point n, In + I1 = I2. Why Vn  = Vp = V2???

Lecture 5 slide 12: 

Lecture 5 slide 13:
    
Lecture 5 slide 14:
    
    
Lecture 5 slide 15:    

    

Lecture 5 slide 16:
    
    
Lecture 5 slide 17:
    
    
Lecture 5 slide 18:
    
Lecture 5 slide 19:
    

Lecture 5 slide 28:    
    
Lecutre 5 slide 41:  
    
Lecture 6 slide 9:  example 1
    response is eqaul to source voltage divided by output voltage,it seems in this case,
impedance to respresent the voltage,? only capacitor's impedance counted for output voltage,
# ?cut off angular frequenc is equavalent to 1/RC?

# %%
#Lecture 6 slide 18: example 2 single order low pass filter
import numpy as np
import math 
cutoff_frequency = round(1/(2*3.14*1*0.1),1)
print("cut off frequency is",cutoff_frequency,"kHz")

source_voltage = 10
source_frequency =2
resistance = 1
capacitance = 0.1
output_voltage = (1/(math.sqrt(1 + pow(2*3.14*source_frequency*resistance*capacitance,2)))) * 10
print("Output voltage is",round(output_voltage,2))
# Out:
# cut off frequency is 1.6 kHz
# Output voltage is 6.23

# %%
#Lecture 6 slide 24:example 3 high pass filter
import math
import numpy as np
import sklearn 
from sklearn import datasets
from sklearn import svm

# %%
#Lecture 6 slide 27 example 4 high pass filter desing
import math
import numpy as np
import sklearn

cutoff_frequency = 10
resistance = 10

capacitance = (1/(2*3.14*resistance*cutoff_frequency))*1000

print("first element which is capacitance of high pass filter is",math.trunc(capacitance),"nF")

# %% [markdown]
# Lecture 6 slide 30 example 6
# output voltage has two components capacitor and resistor in parallel
# why it's $\frac{r}{jωC}$ instead of $\frac{1}{jωC}$ as that is impedance of the capacitor
# maybe for pallell items they are equal to produc of two components divided by submation of two two impedance which is case of this case
#
# Hi Professor:
#
# Regarding to last part of slide at lecture 6 slide 30 example 6, formula is
#
# $\frac{\frac{R}{jωC}}{\frac{R}{jωC}+jωL(R+\frac{1}{jωC})}$
#
# After multiplication denominator and numerator with jωC, it becomes
#
# $\frac{R}{R+jωL(jωCR+1)}$ after further multiplication in denominator I got this
#
# $\frac{R}{R+j^2ω^2RLC+jωL}$
#
# however, in the slide you answer is
#
# $\frac{R}{R-ω^2RLC+jωL}$
#
# it seems like
# $j^2$ is equal to -1 base on your answer. That's how function transformed??
#
# can you explain in more details?
#
# Kevin Lin
#
#
# source voltage has three components an inductor in series with capacitor and resistor

# %%
# lecture 6 slide example 8 
#50ohm refers to source which signal we need to filter. It shows up in the first of first
# which is $g_o$. if question states that it has 3dB bandwidth is 50 Hz that means that it has cut off     
# frequency is 50 Hz 
# we can either use serials meaning inductor is in series and capacitor in shunt  alternatively, we can use capacitor in series and inductor in shunt#  first we need calculate how many order of circuit
# n = refer to forumula section = 2.51, that means more than 2 elements, then choose 3
# Secondly, we calculate  $g_0$ = $g_n+1$ =  = 1. what does 1 mean actaully??
# $g_1$ = 1,.......$g_3$ = 1
# first sceneiro inductor in series
# Capacitance $L_1$ = $L_3$ =  $L_k$ = $\frac{Z_o g_k}{\omega_c}$    lecture 6 slide 36
# Since $Z_o$ refers to impedance of resistor which has same value of resistor
    
import numpy as np
import math
cutoff_frequency = 400000000
frequency_attenuation = 1000000000

A = 20

n = round((math.log(pow(10,A/10)-1))/(2*math.log(frequency_attenuation/cutoff_frequency)),0)

print("order of this filter n is", n)

g0 = 1

g4 = 1

k1 = 1
g1 = 2 * math.sin((2*k1-1)*3.14/(2*n))
print("value of first element g is ", round(g1,0))

k2 = 2
g2 = 2 * math.sin((2*k2-1)*3.14/(2*n))
print("value of second element g is ", round(g2,0))

k3 = 3
n2 = n*2
g3 =  2*math.sin((2*k3-1)*3.14/(2*n))
print("value of third element g is ", round(g3,0))

Z0 = 50
L1 = (Z0*g1/(2*3.14*cutoff_frequency))*1000000000
print("Inductance of first inductor is ", round(L1,1),"nHz")

L3 = L1
print("Inductance of third inductor is ", round(L3,1),"nHz")

C2 = g2 / (50*2*3.14*cutoff_frequency)*1000000000000

print("capacitance of second capacitor value is ", round(C2,1),"pF")

C1 = (g1/(Z0*2*3.14*cutoff_frequency))*1000000000000

print("capacitance of second capacitor value is ", round(C1,2),"pF")
# Out:
# order of this filter n is 3.0
# value of first element g is  1.0
# value of second element g is  2.0
# value of third element g is  1.0
# Inductance of first inductor is  19.9 nHz
# Inductance of third inductor is  19.9 nHz
# capacitance of second capacitor value is  15.9 pF
# capacitance of second capacitor value is  7.96 pF

# %%
#Lecture 6 slide 44 example 9
import numpy as np
import math
k1 = 1
n  = 3
Lr = 0.05
Lr_1 = Lr/10
#If question asks to has ripple value in dB that means it is equal ripple low pass filter
#F1 = 0.25*ln(coth(Lr/17.372)) #=> slide 42, what is F1 and F2??
c  = math.cosh(Lr/17.372)
s  = math.sinh(Lr/17.372)
cutoff_frequency = 1000000000 #cut off frequency is 1GHz

dynamic_frequency = 1000000100

#for x in range(1,100):
#    a = cutoff

X = dynamic_frequency/cutoff_frequency

C_0_X = 1
C_1_X = X
C_2_X = 2 * X * C_1_X - C_0_X
C_3_X = 2 * X * C_2_X -C_1_X

F0 = pow(10,Lr_1) - 1
response_frequenc = 1/(1 +  F0*C_3_X)


F1 = 0.25*math.log1p(c/s)
F2 = math.sinh(2*F1/n)

F1 = 0.25*math.log1p(c/s)
a1 = math.sin(((2*k1-1)*3.14)/(2*n))
b1 = pow(F2,2) + pow(math.sin(k1*3.14/n),2)
g1 = 2 * a1/F2

k2 = 2
a2 = math.sin(((2*k2-1)*3.14)/(2*n))
b2 = pow(F2,2) + pow(math.sin(k2*3.14/n),2)
g2 = (4*a1*a2)/(b2*g1)

k3 = 3
a3 = math.sin(((2*k3-1)*3.14)/(2*n))
g3 = g1

Z  = 50
w  = 2*3.14*1000000000
L1 = (Z*g1)/(w) * pow(10,9)
L3 = L1

C0 = 1
C2 = (g2)/(Z*w) * pow(10,12)

print("Inductance of first inductor is",round(L1,0),"nH")
print("capacitance of second capactitance is",round(C2,3),"pF")
print("Inductance of third inductor is",round(L3,0),"nH")
# Out:
# Inductance of first inductor is 7.0 nH
# capacitance of second capactitance is 3.543 pF
# Inductance of third inductor is 7.0 nH

# %%
#Lecture 6 slide 50 example 10 band-pass filter
ripple_Lr = 0.5
n  = 3
centre_frequency = 1000000000#centre frequency means the frequency on the middle  
                             #as important as cutoff frequency 
Z_0 = 50
bandwidth = 0.1
#from pozar page 406

g_0 = 1  
g_1 = 1.5963  
g_2 = 1.0967   
g_3 = 1.5963  
g_4 = 1

#first element and third element are equal since g1=g3 

L_s_1 = ((Z_0 * g_1)/(bandwidth*2*3.14 * centre_frequency))*1000000000

print("Inductance of third inductor is",round(L_s_1,0),"nH")

L_s_3 = L_s_1

C_s_1 = ((bandwidth)/(2*3.14*centre_frequency * Z_0 *g_1))*1000000000000

print("Capacitance of first capactior is",round(C_s_1,4),"pF")

C_s_3 = C_s_1

L_p_2 = (bandwidth*Z_0)/(2*3.14*centre_frequency*g_2)*1000000000

print("Capacitance of first capactior is",round(L_p_2,4),"nH")

C_p_2 = (g_2)/(Z_0*2*3.14*bandwidth*centre_frequency)*1000000000000

print("capacitance of pallrel is",C_p_2,"pF")

#where s stands for series

#how do we plot response then?????
# Out:
# Inductance of third inductor is 127.0 nH
# Capacitance of first capactior is 0.1995 pF
# Capacitance of first capactior is 0.726 nH
# capacitance of pallrel is 34.92675159235669 pF

# %%
#lecture 6 example 11 to be continued...

# %% [markdown]
# Lecture 7 slide 27:
#
# Lecture 7 slide 29:
#
# Lecture 7 slide 30:
#
# Lecture 7 slide 37:
#
#
# Lecture 7 slide 44:
#
# Lecture 7 slide 50:
#
# Lecture 7 slide 64:

# %%
______________________________________________________________________________________________
Jan 8th

Sensor collects physical signal. 

Transduce transfer to machine. It has analog that converts the  machine sensor data into human readable value

Another step called signal conditioning. basically convert signal into human readable data

Instrument span means maximum of calibration point minus minimum point of
calibration. 

To determine what maximum of instrucment can undergo, 
resolution matters, if they are same resolution. we look forward repeatablility.

First order instrument means the measurement is not as fast as it supposed to be.

60.2% is called tao when they reach steady state; place one electorde in 0 C 
and the other in 100 C. Measure the t when it reaches 63 C. that's called thermal constant.

Tao is stead state. It basically means how fast it can read the steay stateTao is the time 
to reach from 60% of final destination.

Dynamic of instrument refers to outout of vaiable depends on the input if it does not change, 
that means it is static.

Jan 15th, 

Inductance,when a current pass through an conductor, it generates voltage in that conductor,
that's voltage is called inductance, I assuem unit is voltage. 

Capacitance, capacitor is a device for electronic storage, capcitance is used to measure
how much energy it can stored. Two plates are guarded by an insulator and also called 
dielectric.


attery is also stored energy but it release energy slowly
but capacitor release quickly.

Resistance, is oppsite of current. a resistor has resistance. unit is ohm. They can be 
further divided into conductor such as copper, steal or insulator such as rubber. 

Integration basically the value respect to that variable at top variable minus bottom variable
in a circuit, power suppose to be balanced meaning the summation of each element is 0. 

One thing confuse me is that when the current pass through the wire, how come it does not
consider as resistor because it's negnegible by convention. 

Proton does not move,only electron moves. electron flows a to b then current flow from point b to a
The charge per electron is -1.602×10-19 C. Elementary charge is 1.602 x 10^19C which is positive

Electron flows direction is opposite of current since current move from
postive to negative. 

charge is -infinite means from long time ago at moment i intereste
Power is how much energy consume over time. Ampere/hour as you see in battery unit.

Current is entered in positve side of voltage |l, means that they absorb energy,
positive side or negative side refers to the voltage not the current; This refers to voltage source. 

However, current has either positve or negative value. If current enter positive side of resistor, 
the reading value is as is when we calucate the power, 

If current enter negative side of voltage, when we calculate the power, it is negative of 
reading value. In this convention,voltage is alway positive since it refers to potential difference. 

for example, battery enter negative side, means they provide energy

positive energy or power refers to absorbed by the element; 

negative energy or power refers to supplised by the element;

Regarding to nodes, entering point is considered as negative value, 

exiting the node is consider positive value when applying KCL 


Convention for writting potential, either potential loss or potential gain


black electrodie is reference point,

red electrode, voltage just meausre the voltage potential;

voltage multiply current is power, I * V = P  , the minus power means supply power

number of component is number of branches and denoted as B. voltage source is also 

considered as component. 

Kirchhoff Current Law(KCL) : 

the sum of current at node is 0. In this case, we can apply into multiple equation

we can run

indepedent source: indepent voltage or indepenent current; 

amplifier: 


or dependent source voltage and current. pass through amplifer and gets largers


circular shape indepent;

square shape is dependent ; 



the node is defined component ....

nodes is the net without component;at least two elements connects to it.

In a net or node, their voltage is same; 


Loop: come back to same point.It does not have to be a physical loop but belong
to same circuit. the summation of that path is 0. the voltage sources have to be same
voltage and can not be different. If they are different, what happened?


if we loss or positve depends on how you entered the system.

if the component is Resistenace which is always absor energy, means the loop enter
postive and leave negative and we write positve for voltage,

Vbe means b is postive and e is negative, point b has higher voltage than point a. 



Vae means put red electrode on the a and black electrode on the e;

loop just basically (KVL examples), when we count non-physical loop, whichever point that 
takes two indices also accounts for the KVL formular.



______________________________________________________________________________________________


Trigonometric Identities: use the chart as example;
    
    
the one on top is sin frequncy redius t, 

the one on right is cos frequncey redius t,

the one on the bottom is -sint which is sin(t+180) 

the one on the left is -cos(t) which is c


    
    
    
sinusoids, it seems only refer to voltage. not really, basically, it's the comparison between
current and voltage. When current reaches maximum but not current etc.

    

total phase,

retangular representation ,  wl90,



impedance,which is opposite of current. it's from creation of resistor but has phase
meaning it has.

DC only has resistance.
Besides resistance, AC has reactance which capcitive and inductive forms.
The combination of resistance and reactance are called impedance. 

i(t) = cdv(t)/dt; V(t) = L..., Q is CV, ,,,





they are all function of frequency denoted by f;

ZeroDivisionError = ...., If

example 7: every node has own voltage,  has three nets or nodes.

phase angle,

电阻 is called resistor

node, if is entering is negative, exist is positve, 

potential gain as positive is the case that when the loop direction entering from negative of 
terminal to the positive terminal. intuitively, it gains the potential then it is positive.

It's negative when the potential loss means that loop enteres from positive sign to negative.
If they flow in the opposite way, then means it's negative

Potential loss as positive, when the loop direction goes from positive side to negative side; 

______________________________________________________________________________________________
Jan 22nd, 

conductivity unit is Simeon/second. That answers one of my longest question, conductivity of
liquid in the water as same as the one conductor or resistor. 


resistivity only resistor has it. 


elsilon is ? of material

inductive conduction primary coil, secondary coil, and third coil. these are inductor. 

upper wire and lower wire adds up total wire voltage. such as black electrode and read
electrode. they have two layers. outer layer and inner layers. 

temperatur can see whehter they gain energy or loss energy


measure the 4 points of temperature and calibrate it, see website, 


______________________________________________________________________________________________


z denoted as complex number of phasor; 


phasor needs to have same function,

Time domain means the value of voltage/current calculation depending on time. It makes sense that a AC 
needs time to reach its maximum. 

Phasor domain denoted as phasor \angle F(theta) means voltage calculation depends on 
phasor which is a complex number denoted as z. which can be expressed as retangular form?? and
polar form??. 


example 7 slide 54 lecture 2

F => what is this unit for?

 accroding to phase convention, sin is cos counterclosewise for 90
degree 

Z = j w L where z is called impedance of an inductor, L is called inductance and unit is henry,
once we know the inductance of an inductor, then we will know the impedance of the inductor. 


2sin(100t)    => 2cos(100t - 90) =  2 phasor -90
1.5cos(100t)  => 1.5 phasor 0
0.1H Z=> j w L => j w 0.1 ohm, in this circuit, w = 100, then it becomes  j 10 ohm which is 
impedance, the reason why value is alway positve is because this is inductor

Zc = -1 /(j w C) => where C is capacitance => -1 / (j 100 0.002) =  5 j ohm; the reason why
this is always negative because it's capacitor;

wher f = 1/T hz ; w = 2 pi f; w can is same for entire circuit. 

apply KVL law, left side is a loop, the current is V1 = V10R 
then we apply KCL,V1 is a node, current in equal to current out, 

then apply the rules; 



capacitor current can be calculated as voltage in and voltage out divided by impedance. 




our goal to to convert given value into cos(wt), known become our target not start variable.
Phasor sign is cos(wt+90)



circuit symbol:
    
    \/\/\/\/\/ mountain shape is resistor
    (((((()))))) coil shape is inductor
    parallel vertical symbol is capacitor
    one vertical and one curve is polorized capacitor
    high and low vertical symbol is voltage source
    an single arrow circled by a circle is current source
    




Oscilator is an amplifier with positive feedback.

# %%
On Jan 8th and 15th, instructor has asked student whether wants to take break
or just class straight. All of class members agree without break only me propose
to have 5 mins break in order for ppl to go to washroom. However, he didn't listen
and proceed every class without even 5 mins break. Even though 5 mins does not
cover too much class material but I definitely deserve I have full access to class
content.

instructor is sitting on the chair and read the slides. When he finish his slides, he did
not ask student whether we understand materail or not. I have to intentionally interrupt him
for certain points he does not explanin properly

# %% [markdown]
# Feb 5th
#
# Current is 0 when entering op amplifier meaning that potential is also 0;
#
# Only negative feedback not positve feedback because it's not stable when we design amplifier.
# Meaning that after signal passed through amplifier, the loop should return to it's negative side
#
# Positive feedback connects to ground in amplifier design.
#
# Transfer function for inverting amplifier????key point is to amplify the voltage
#
# there is no curretn go into op amp, meaning the current go to the other loop,
#
#
# non-inverting input means positive voltage enters positive side of amplifier.
# inverting input means positive voltage enters into negative side of terminal.
#
# there is no phase change,
#
# inverting amplifier phase changes 180. current is o and voltage is 0 at that line
#
# transformer is passive device which we can't use it
#
# amplifier does not kill signal; extra energy to make it stronger not transformer
#
#
# adder inverter
#
#
# because of ground, the enterinng voltage is also 0;
#
#
# non-interting amplifier means entering non-inveritng ampilider which is positive side ;
#
# example 1: 5 ....19.5k omu
#
#     20k
#
#
#
#
# the source has the current, passing through
#
# inverting amplifier tranformer function:
#
# non-inverting amplifier transformer function:
#
#
#     V0 / 1v =
#
#
#     v0 is defined
#
#     this is a midterm question, at slide 16
#
#
#     non-inverted amplifier : V0 / Vs = 1+R2/R1
#     inverting amplifier : Vout = - (R2/R1)* V
#
#         Vs is voltage of source,
#
#         Vo is voltage of out,
#
#
#         nosiy cancellation circuit is basically differential amplifier
#
#
#
#
# buffer is to create the interface between source signal and amplifier
#
# Rg can provide how much gain for instrumentation the gain
#
# if Rg is infinity and it will end up with 1.
#
# Any signal that comes from differntial equation, they will be cancelled.
#
#
# Feb 12
#
# omega = 1/R  :  Z = 1/ J* w * c
#
#
# filter,  dB refers to
#
# 0dB means all of signal has passed through output theoretically.
#
# fc is cut off frequency
#
# what type of filter and order (n) we want.
#
# higher order of filter,
#
# cut off frequency means the db goes to below 0db. slope = -40 db/decade
#
# filter is to provide dB,
#
# s = j omega
#
# 1/R C => point between stop band
#
# RC circuit => resistor and capacitor circuit
#
# frquency depednent
#
# low pass filter because frequency increase, means pass throuhg low frequency
#
# high pass filter means pass through high frequency
#
# Serial elements (g) => starts with capacitor, second one is inductor, third one is capacitor....
# meaning inductor is in seriss. and capacitor is shunt.
#
# shunt elements(g)  => starts with inductor, capacitor
#
#
# it seems g refers to section of element in LPF or HPF,
#
#
#
# Lets say we need 6 orders of filter, then we calculate the g1, g2....g6. then g7 is
#
# example
#
# Ro = g = 50 ohm =>
#
# A = 20 dB
#
# calculate order n = .... = 2.51. order should be greater than 2.51 , then n is 3
#
# means we have g1, g2, g3, => inductor, inductor, resistor,
#
# go = 1, gn+1 = g4 =1
#
# g is impedance????
#
# the filter will go 1st capacitor 2nd is inductor
#
# go is resistor and last element is gn is resistor,
#
#
# scaling imepedance, Lk and Ck is scaling, Ck is capacitor
#
# ultimate goal of filter is to provide
#
# resistor is impedance;
#
# Inductor unit is Henry which is inductance. we use L to denoted as L = 1 Henry etc.
# If current is 1 A Then inductance is 1 Henry??
#
# capacitor unit is Farad denoted as F and it's actual unit is coulomb per volt. Value ranges
# from pF(pico Farad) to uF(micro Farad).
#
# 3dB ripple,
#
# minimum order is 1.
#
# the higher the ripple,
#
# 3 section means 3 order; ripple is 0.05 dB means very tight.
#
# 50 ohm means next circuit is 50 ohm. then we can design backwards
#
# low pass filter to
# band pass filter => replace inductor in serires  with inductor and capacitor in series;
# replace capacitor shun with inductor and capacitor shun;
#
# s is serioes
#
# p is parallel
#
# it goes to L1, C2, L3,
#
#
#
# if g1 and g3 same, then we can assume Ls1 and Ls2 same
#
# 3 resilator and 0.5 ripple,
#
# take output of filter and place input of amplifier,
#
# crital frequency and cut-off frequency are same.
#
# Vf can be written as Vo = >
#
# ideal op amp have same
#
# voltage division:???
#
#     -20dB per
#
#     20dB means remaining is 10%
#
# operational amplifier is a 3-terminal device.
#
# it has at least fine terminals.
#
# assignment 1:
#
# using matlab, slide 47, r we simulating low pass, high pass => then we go to
#
# Feb 25
#
# wifi signal is digital signal.
#
# sample oh hold as well as buffer.
#
# aliasing happens under sample of signaling.
#
# circles means inverting buffer.
#
# slide 23 , in digital, the idea is not to lose signal, we are not losing singal, we
# discretizing the voltage.
#
# digital has 10 bites, analog has 8 bits.
#
# differential amplifier is basically non-inverting amplifier combine with inverting amplifer.
#
# Then Vo = R2 /R1 (V2 - V1)
#
# instumentation amplifier. the disadvantage of op amp is input singnal is very small???
# to avoid this
#
#
# flat filter :
#
# There are 4 types of filter response butterworth filter, cheybyshev 1 and cheybyshev 2,Elliptici:
#
# EAGLE, => new project => new schematic => click add part =>  library manager => ng spice simulation, we can find all of stuff =>
# adafruit => in use => ngspice => add => right click component => choose propperty =>
# net is routing =>
#
# click refer to slide 39 lecture 6 to enter value, click property to enter value of each
# component
#
# right click the component => click value => enter the value
#
# click simulate will see =>
#
# voltage probe button => and come to net click it =>
#
# click signal => remove current => apply changes
#
# while entering value, there should be no space bewteen number and unit
#
# starts 500 points to 20000 point.
#
# click zoom to fit
#
# when we do net, we need make whole circle unitl it all appears
#
# click simulate AC sweep, start freq 100k , end Freq 2G
#
# points 500 and 20000; click simulate  => uncheck current then click apply, we will see
# at 3, we will 400 something??/
#
#
# click recyle bin then comonent then we can delte it
#
# this teaches you how to draw graph; good for final project
#
#
# second eagle plot slide 52, voltage is AC 2V; ???
#
# slide 62, AC sweep, start freq 0.1k end freq 20k , start time 1 stop time 1000,
# point 500 and maxium points 2000
#
# in assignment, gain is 20dB needs to change to meaning is -20dB. only low pass filter for
# assignment
#
#
#
#
#
# %example 9 slide 44 lecture 6
#
# %
#
# %F1 = 0.25 ln{coth(Lr/17.32)} => slide 42, what is F1 and F2??
#
# %F2 = sinh (2F1/n)
#
# % Lr ripple attenuation in pass-band
#
# % question is asking for frequncy response for an equal-ripple where H(w) which is V0 /Vs,
#
# % H = 1 + F0
#
# % n = order of filter
#
# % x-axis is cutoff frequency at different values of repsonse
#
# % curve is cut-off frequency and y-axis is Vo / Vs
#
# ripple = 0.05
# order = 3
# cutofffrequency = 1
#
# % formula for cutofffrequency of low pass filter
# % fc = 1/(2 * pi * resistance * capacitor )
# F1 = 1.4626
# F2 = 1.1371
#
#
#
#
# The purpose of OP AMP is to obtain gain of voltage as output after voltage gain, signal become stronger???
#
# RG refers to Resistor Gain in amplifier.
#
# low pass filter (LPF) => only low frequency can pass through, high
#
# %frequency filter out. From 0Hz to critical frequency, other
#
# % frequency filter out ,band refer to frequqncy range, pass band refers to
# % the range of frequency that signal passes
# %stop band is the frequency range that filter filter them out
#
# % order of filter basically means that the number of resistors that from voltage source
# % prior passing throuhg filter. if one then is first order
# % rippl unit is dB. It occurs ripple is calculated as 20 log ???slide 14 lecture 6
# % Wc is cut off frequency then what about W0 and W?????
# % y-axis is in dB unit meaning voltage ratio. gain = 10log (Vout/Vin)
# cut off frequency in low pass filter refers to -3dB response, and typically
#
# Xc refers to capacitor reactance. capacitor reactance can be calculated as 1/2 π f C and unit
# is ohm. It's unit is as same as resistance of a resistor.
# that makes sense that at low freuqncy, signal voltage is equivalent to outout voltage.
# at hight frequncy, it filters out and output voltage drops gradually to 0.
# we have to refer to low pass filter response pattern in order to figure out whehter it's low
# pass filter or high pass filter. by providing the frequncy and calculating the output voltage.
#
# g0, g1, g2, g3, g4, g5.... they represents order of elements
#
#
#
# open circuit means that means that circuit is disconnected.
#
# it can be caculated through Xc = 1/(2 π f C)
#
# ω / ωc : refers to variable frequency divided by cut off frequency.
#
#
# whereas f is frequency and C is capacitance in Farad such as uF when I drew
#
# if frequncy is low, that means capacitor reactance is high,
#
#
# circuit in Eagle software
# cut off frequency formular for fc  = 1 / (2 π ω C) where R is resistance value in ohm
# C is capacitance in F or uF. slide 18. source of voltage is also having frequency
# Vout / V in = / square root (1 + ωRC)^2. where w = 2 pi f which is source frequency
#
# high pass filter is opposite of low pass filter, it has stop band first then pass band
# meaning that it filter out all of frequncy that below cut off frequncy.
# how do i tell circuit is filter or amplifier?
#
# H = V0/Vs = jω L / ( R + jωL) => low pass circuit formula
#
# H = V0/Vs =
#
# upto slide 36 of lecture 6
#
# Maximally flat or butterworth low pass filter:??? refer to slide 36 lecture 6
#
# equal ripple filter :
#
#
#
# Mar 11, 2020
#
# MEMS technology:
#
# wafer:
#
# lithography:
#
# etching:
#
# silicon is type of semiconductor,
#
# thin film technology =>
#
# wet etching is pure chemical
#
# dry etching really depends on ??
#
# When we design a filter, we need to place the input positive and negative voltage and output voltage of positive and negative.
#
#
# analog signal  filter divided into element filter and frequency fitler and frequency filter signal divided into low pass and band pass etc
#
# since filter is response of frequency, the response is plot of potential gain over frequency. The goal of amplifier and filter is output voltage.
#
#
# 0dB meaing the signal is at it's strongest point for low pass,-1dB frequency is increaing, -2dB frequency is decreasing again. -3dB is defined as cut off frequency.
#
# capacity if part of filter??
#
# high order low pass is basically combining of single capacitor and resistor.
#
# up to example 6 slide 40
#
# so the first resistor and last resitor is also part of circuit.
#
# band pass filter means the pair of inductor and capacitor serves as first element, they are together serves as one element which is g1. and g2 is pair of inductor and capacitor on the second element.
#
#
# passive filter has best gain at 1.
#
# so we need to active filter,
#
# each RC filter set represent a pole. termed single pole.
